# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import tensorflow as tf
import tensorflow.keras as keras
import os
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import tqdm
from tensorflow.keras.utils import Sequence, to_categorical
from keras.utils.np_utils import to_categorical
import tensorflow_datasets as tfds
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D, Dropout, BatchNormalization, UpSampling2D, InputLayer
from tensorflow.keras.layers import Input
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import average_precision_score

# %% [markdown]
# ## __Load dữ liệu train, test, val__

# %%
# make shorcut cho folder CS114-ML trước
# %cd "/content/gdrive/MyDrive/CS114-ML/data_ndarray"
# Out:
# /content/gdrive/.shortcut-targets-by-id/12IVdVQOkY2icQgpyJaH6y16BPdip3RKW/CS114-ML/data_ndarray

# %%
with open('X.npy', 'rb') as f:
    X = np.load(f)
with open('y.npy', 'rb') as f:
    y = np.load(f)

# %% [markdown]
# ## __Cài đặt mô hình__

# %%
df = pd.DataFrame(columns=["model", "fold_1", "fold_2", "fold_3", "fold_4", "mWAP", "std"])

# %%
# khai báo số lượng class và shape ảnh training
num_classes = y.shape[1]
input_shape = X.shape[1:]

# %%
# training config
base_learning_rate = 0.0001
epochs = 25
batch_size = 64

checkpoint_path = "/content/gdrive/MyDrive/CS114-ML/checkpoint/efficientnet"

callbacks = ModelCheckpoint(
        filepath=os.path.join(checkpoint_path, "efficientnet-{epoch}.h5"),
        save_best_only=True, 
        monitor="val_loss",
        verbose=1)

# %%
def get_model():
  # khai báo mô hình CNN sử dụng
  base_model = tf.keras.applications.EfficientNetB0(include_top=False, weights="imagenet", input_shape=input_shape)

  # đóng băng (k cập nhật trọng số khi training) toàn bộ base_model
  base_model.trainable = False

  input_layer = tf.keras.Input(shape=input_shape) # khởi tạo input layer

  rescale = tf.keras.layers.Rescaling(1./255) 
  x = rescale(input_layer) # scale ảnh từ [0, 255] về [0, 1]
  x = base_model(x, training=False) # đưa kết quả input_layer vào base_model
  x = tf.keras.layers.GlobalAveragePooling2D()(x) # "flatten" kết quả đầu ra của base_model thành vector 1 chiều

  output_layer = tf.keras.layers.Dense(num_classes, activation="sigmoid")(x) # khởi tạo output layer - dự đoán toàn bộ 

  model = Model(inputs=input_layer, outputs=output_layer) # ghép input layer và output layer lại thành 1 model hoàn chỉnh

  model.compile(loss='binary_crossentropy', 
              optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              metrics=['accuracy'])
  
  return model

# %%
def evaluate_model(X, y):
  ap_results = [] # khai báo biến chứa kết quả ap của từng fold
  
  cv = RepeatedKFold(n_splits=4, n_repeats=1, random_state=1)
  
  for train_ix, test_ix in cv.split(X):
    X_train, X_test = X[train_ix], X[test_ix]
    y_train, y_test = y[train_ix], y[test_ix]
    print("1")

    model = get_model()
    print("2")
    model.fit(X_train, y_train, verbose=1, epochs=epochs)

    y_pred_scores = model.predict(X_test, batch_size=batch_size, verbose=1)
    y_pred_scores = np.around(y_pred_scores, decimals=3)

    weighted_ap = average_precision_score(y_test, y_pred_scores, average='weighted')

    print('>%.3f' % weighted_ap)
    ap_results.append(weighted_ap)

  mwap = np.round(np.mean(ap_results), 3)
  std = np.round(np.std(ap_results), 3)
  print('mAP: %.3f (%.3f)' % (np.mean(ap_results), np.std(ap_results)))
  ap_results = np.around(ap_results, decimals=3)
  df.loc[0] = ["efficient_net"] + [ap_results[0]] + [ap_results[1]] + [ap_results[2]] + [ap_results[3]] + [mwap] + [std]
  return ap_results

# %%
results = evaluate_model(X, y)
# Out:
# 1
# 2
# Epoch 1/25
# 95/95 [==============================] - 8s 41ms/step - loss: 0.5700 - accuracy: 0.0356
# Epoch 2/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.4109 - accuracy: 0.0109
# Epoch 3/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.3281 - accuracy: 0.0458
# Epoch 4/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2839 - accuracy: 0.0866
# Epoch 5/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2592 - accuracy: 0.0520
# Epoch 6/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2449 - accuracy: 0.0642
# Epoch 7/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2362 - accuracy: 0.0741
# Epoch 8/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2308 - accuracy: 0.0412
# Epoch 9/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2273 - accuracy: 0.0905
# Epoch 10/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2251 - accuracy: 0.0724
# Epoch 11/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2236 - accuracy: 0.0754
# Epoch 12/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2226 - accuracy: 0.0905
# Epoch 13/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2220 - accuracy: 0.0905
# Epoch 14/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2216 - accuracy: 0.0629
# Epoch 15/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2213 - accuracy: 0.0896
# Epoch 16/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2210 - accuracy: 0.0859
# Epoch 17/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2209 - accuracy: 0.0652
# Epoch 18/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2208 - accuracy: 0.0869
# Epoch 19/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2208 - accuracy: 0.0899
# Epoch 20/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2207 - accuracy: 0.0425
# Epoch 21/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2207 - accuracy: 0.0905
# Epoch 22/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2207 - accuracy: 0.0445
# Epoch 23/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2207 - accuracy: 0.0905
# Epoch 24/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2207 - accuracy: 0.0550
# Epoch 25/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2206 - accuracy: 0.0905
# 16/16 [==============================] - 2s 70ms/step
# >0.182
# 1
# 2
# Epoch 1/25
# 95/95 [==============================] - 8s 42ms/step - loss: 0.5835 - accuracy: 0.0089
# Epoch 2/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.4198 - accuracy: 0.0286
# Epoch 3/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.3338 - accuracy: 0.0115
# Epoch 4/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2877 - accuracy: 0.0115
# Epoch 5/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2620 - accuracy: 0.0115
# Epoch 6/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2470 - accuracy: 0.0115
# Epoch 7/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2378 - accuracy: 0.0115
# Epoch 8/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2321 - accuracy: 0.0115
# Epoch 9/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2285 - accuracy: 0.0119
# Epoch 10/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2261 - accuracy: 0.0115
# Epoch 11/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2245 - accuracy: 0.0115
# Epoch 12/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2235 - accuracy: 0.0119
# Epoch 13/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2228 - accuracy: 0.0115
# Epoch 14/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2223 - accuracy: 0.0115
# Epoch 15/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2219 - accuracy: 0.0115
# Epoch 16/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2217 - accuracy: 0.0115
# Epoch 17/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2216 - accuracy: 0.0115
# Epoch 18/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2215 - accuracy: 0.0115
# Epoch 19/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2214 - accuracy: 0.0115
# Epoch 20/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2213 - accuracy: 0.0115
# Epoch 21/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2213 - accuracy: 0.0115
# Epoch 22/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2213 - accuracy: 0.0115
# Epoch 23/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2213 - accuracy: 0.0115
# Epoch 24/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2213 - accuracy: 0.0115
# Epoch 25/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2213 - accuracy: 0.0115
# 16/16 [==============================] - 2s 71ms/step
# >0.183
# 1
# 2
# Epoch 1/25
# 95/95 [==============================] - 8s 43ms/step - loss: 0.5671 - accuracy: 0.0619
# Epoch 2/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.4092 - accuracy: 0.0948
# Epoch 3/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.3274 - accuracy: 0.0701
# Epoch 4/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2839 - accuracy: 0.0908
# Epoch 5/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2598 - accuracy: 0.0816
# Epoch 6/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2457 - accuracy: 0.0941
# Epoch 7/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2372 - accuracy: 0.0556
# Epoch 8/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2319 - accuracy: 0.0599
# Epoch 9/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2286 - accuracy: 0.0234
# Epoch 10/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2264 - accuracy: 0.0783
# Epoch 11/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2250 - accuracy: 0.0948
# Epoch 12/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2240 - accuracy: 0.0418
# Epoch 13/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2234 - accuracy: 0.0839
# Epoch 14/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2229 - accuracy: 0.0777
# Epoch 15/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2226 - accuracy: 0.0586
# Epoch 16/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2224 - accuracy: 0.0701
# Epoch 17/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2223 - accuracy: 0.0142
# Epoch 18/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2222 - accuracy: 0.0741
# Epoch 19/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2222 - accuracy: 0.0668
# Epoch 20/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2221 - accuracy: 0.0803
# Epoch 21/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2221 - accuracy: 0.0155
# Epoch 22/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2221 - accuracy: 0.0948
# Epoch 23/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2221 - accuracy: 0.0770
# Epoch 24/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2220 - accuracy: 0.0293
# Epoch 25/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2220 - accuracy: 0.0945
# 16/16 [==============================] - 2s 84ms/step
# >0.195
# 1
# 2
# Epoch 1/25
# 95/95 [==============================] - 9s 42ms/step - loss: 0.5748 - accuracy: 0.0151
# Epoch 2/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.4140 - accuracy: 0.0125
# Epoch 3/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.3300 - accuracy: 0.0125
# Epoch 4/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2851 - accuracy: 0.0142
# Epoch 5/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2600 - accuracy: 0.0237
# Epoch 6/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2453 - accuracy: 0.0408
# Epoch 7/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2364 - accuracy: 0.0599
# Epoch 8/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2309 - accuracy: 0.0352
# Epoch 9/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2273 - accuracy: 0.0467
# Epoch 10/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2250 - accuracy: 0.0458
# Epoch 11/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2235 - accuracy: 0.0609
# Epoch 12/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2224 - accuracy: 0.0849
# Epoch 13/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2217 - accuracy: 0.0201
# Epoch 14/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2213 - accuracy: 0.0513
# Epoch 15/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2210 - accuracy: 0.0596
# Epoch 16/25
# 95/95 [==============================] - 4s 41ms/step - loss: 0.2207 - accuracy: 0.0408
# Epoch 17/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2206 - accuracy: 0.0533
# Epoch 18/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2205 - accuracy: 0.0408
# Epoch 19/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2204 - accuracy: 0.0928
# Epoch 20/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2204 - accuracy: 0.0935
# Epoch 21/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2204 - accuracy: 0.0662
# Epoch 22/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2203 - accuracy: 0.0402
# Epoch 23/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2203 - accuracy: 0.0543
# Epoch 24/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2203 - accuracy: 0.0754
# Epoch 25/25
# 95/95 [==============================] - 4s 42ms/step - loss: 0.2203 - accuracy: 0.0504
# 16/16 [==============================] - 2s 70ms/step
# >0.191
# mAP: 0.188 (0.005)

# %%
file_name = "efficientnet_evaluation.csv"
save_path = os.path.join(checkpoint_path, file_name)
df.to_csv(save_path)
