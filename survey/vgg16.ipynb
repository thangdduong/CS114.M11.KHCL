# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import tensorflow as tf
import tensorflow.keras as keras
import os
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import tqdm
from tensorflow.keras.utils import Sequence, to_categorical
from keras.utils.np_utils import to_categorical
import tensorflow_datasets as tfds
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D, Dropout, BatchNormalization, UpSampling2D, InputLayer
from tensorflow.keras.layers import Input
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import average_precision_score

# %% [markdown]
# ## __Load dữ liệu train, test, val__

# %%
# make shorcut cho folder CS114-ML trước
# %cd "/content/gdrive/MyDrive/CS114-ML/data_ndarray"
# Out:
# /content/gdrive/.shortcut-targets-by-id/12IVdVQOkY2icQgpyJaH6y16BPdip3RKW/CS114-ML/data_ndarray

# %%
with open('X.npy', 'rb') as f:
    X = np.load(f)
with open('y.npy', 'rb') as f:
    y = np.load(f)

# %% [markdown]
# ## __Cài đặt mô hình__

# %%
df = pd.DataFrame(columns=["model", "fold_1", "fold_2", "fold_3", "fold_4", "mWAP", "std"])

# %%
# khai báo số lượng class và shape ảnh training
num_classes = y.shape[1]
input_shape = X.shape[1:]

# %%
# training config
base_learning_rate = 0.0001
epochs = 25
batch_size = 64

checkpoint_path = "/content/gdrive/MyDrive/CS114-ML/checkpoint/vgg16"

callbacks = ModelCheckpoint(
        filepath=os.path.join(checkpoint_path, "vgg16-{epoch}.h5"),
        save_best_only=True, 
        monitor="val_loss",
        verbose=1)

# %%
def get_model():
  # khai báo mô hình CNN sử dụng
  base_model = tf.keras.applications.VGG16(include_top=False, weights="imagenet", input_shape=input_shape)

  # đóng băng (k cập nhật trọng số khi training) toàn bộ base_model
  base_model.trainable = False

  input_layer = tf.keras.Input(shape=input_shape) # khởi tạo input layer

  rescale = tf.keras.layers.Rescaling(1./255) 
  x = rescale(input_layer) # scale ảnh từ [0, 255] về [0, 1]
  x = base_model(x, training=False) # đưa kết quả input_layer vào base_model
  x = tf.keras.layers.GlobalAveragePooling2D()(x) # "flatten" kết quả đầu ra của base_model thành vector 1 chiều

  output_layer = tf.keras.layers.Dense(num_classes, activation="sigmoid")(x) # khởi tạo output layer - dự đoán toàn bộ 

  model = Model(inputs=input_layer, outputs=output_layer) # ghép input layer và output layer lại thành 1 model hoàn chỉnh

  model.compile(loss='binary_crossentropy', 
              optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              metrics=['accuracy'])
  
  return model

# %%
def evaluate_model(X, y):
  ap_results = [] # khai báo biến chứa kết quả ap của từng fold
  
  cv = RepeatedKFold(n_splits=4, n_repeats=1, random_state=1)
  
  for train_ix, test_ix in cv.split(X):
    X_train, X_test = X[train_ix], X[test_ix]
    y_train, y_test = y[train_ix], y[test_ix]
    print("1")

    model = get_model()
    print("2")
    model.fit(X_train, y_train, verbose=1, epochs=epochs)

    y_pred_scores = model.predict(X_test, batch_size=batch_size, verbose=1)
    y_pred_scores = np.around(y_pred_scores, decimals=3)

    weighted_ap = average_precision_score(y_test, y_pred_scores, average='weighted')

    print('>%.3f' % weighted_ap)
    ap_results.append(weighted_ap)

  mwap = np.round(np.mean(ap_results), 3)
  std = np.round(np.std(ap_results), 3)
  print('mAP: %.3f (%.3f)' % (np.mean(ap_results), np.std(ap_results)))
  ap_results = np.around(ap_results, decimals=3)
  df.loc[0] = ["vgg16"] + [ap_results[0]] + [ap_results[1]] + [ap_results[2]] + [ap_results[3]] + [mwap] + [std]
  return ap_results

# %%
results = evaluate_model(X, y)
# Out:
# 1
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step
# 2
# Epoch 1/25
# 95/95 [==============================] - 20s 93ms/step - loss: 0.6369 - accuracy: 0.0221
# Epoch 2/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.4483 - accuracy: 0.0316
# Epoch 3/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.3490 - accuracy: 0.0695
# Epoch 4/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2957 - accuracy: 0.0803
# Epoch 5/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2654 - accuracy: 0.0840
# Epoch 6/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2471 - accuracy: 0.0856
# Epoch 7/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2352 - accuracy: 0.0863
# Epoch 8/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2271 - accuracy: 0.0859
# Epoch 9/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2213 - accuracy: 0.0866
# Epoch 10/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2168 - accuracy: 0.0915
# Epoch 11/25
# 95/95 [==============================] - 6s 65ms/step - loss: 0.2132 - accuracy: 0.0919
# Epoch 12/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2102 - accuracy: 0.0935
# Epoch 13/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2077 - accuracy: 0.0958
# Epoch 14/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2054 - accuracy: 0.0998
# Epoch 15/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2033 - accuracy: 0.1044
# Epoch 16/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2014 - accuracy: 0.1070
# Epoch 17/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1997 - accuracy: 0.1067
# Epoch 18/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1980 - accuracy: 0.1113
# Epoch 19/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1964 - accuracy: 0.1149
# Epoch 20/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1948 - accuracy: 0.1139
# Epoch 21/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1933 - accuracy: 0.1215
# Epoch 22/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1919 - accuracy: 0.1245
# Epoch 23/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1905 - accuracy: 0.1258
# Epoch 24/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1891 - accuracy: 0.1268
# Epoch 25/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1878 - accuracy: 0.1311
# 16/16 [==============================] - 11s 390ms/step
# >0.446
# 1
# 2
# Epoch 1/25
# 95/95 [==============================] - 7s 64ms/step - loss: 0.5989 - accuracy: 0.0079
# Epoch 2/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.4274 - accuracy: 0.0079
# Epoch 3/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.3367 - accuracy: 0.0102
# Epoch 4/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2876 - accuracy: 0.0207
# Epoch 5/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2595 - accuracy: 0.0316
# Epoch 6/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2426 - accuracy: 0.0382
# Epoch 7/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2316 - accuracy: 0.0454
# Epoch 8/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2241 - accuracy: 0.0510
# Epoch 9/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2187 - accuracy: 0.0635
# Epoch 10/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2146 - accuracy: 0.0682
# Epoch 11/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2113 - accuracy: 0.0761
# Epoch 12/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2086 - accuracy: 0.0767
# Epoch 13/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2063 - accuracy: 0.0817
# Epoch 14/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2042 - accuracy: 0.0840
# Epoch 15/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2023 - accuracy: 0.0856
# Epoch 16/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2006 - accuracy: 0.0935
# Epoch 17/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1989 - accuracy: 0.0945
# Epoch 18/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1973 - accuracy: 0.0985
# Epoch 19/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1958 - accuracy: 0.1077
# Epoch 20/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1944 - accuracy: 0.1070
# Epoch 21/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1930 - accuracy: 0.1096
# Epoch 22/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1916 - accuracy: 0.1159
# Epoch 23/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1903 - accuracy: 0.1169
# Epoch 24/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1890 - accuracy: 0.1208
# Epoch 25/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1877 - accuracy: 0.1268
# 16/16 [==============================] - 2s 114ms/step
# >0.476
# 1
# 2
# Epoch 1/25
# 95/95 [==============================] - 9s 94ms/step - loss: 0.6193 - accuracy: 0.0428
# Epoch 2/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.4381 - accuracy: 0.0448
# Epoch 3/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.3428 - accuracy: 0.0915
# Epoch 4/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2915 - accuracy: 0.0987
# Epoch 5/25
# 95/95 [==============================] - 6s 65ms/step - loss: 0.2622 - accuracy: 0.0922
# Epoch 6/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2444 - accuracy: 0.0882
# Epoch 7/25
# 95/95 [==============================] - 6s 65ms/step - loss: 0.2328 - accuracy: 0.0945
# Epoch 8/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2249 - accuracy: 0.1004
# Epoch 9/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2192 - accuracy: 0.0941
# Epoch 10/25
# 95/95 [==============================] - 6s 65ms/step - loss: 0.2149 - accuracy: 0.1017
# Epoch 11/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2115 - accuracy: 0.1024
# Epoch 12/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2087 - accuracy: 0.1083
# Epoch 13/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2063 - accuracy: 0.1139
# Epoch 14/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2042 - accuracy: 0.1162
# Epoch 15/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2023 - accuracy: 0.1172
# Epoch 16/25
# 95/95 [==============================] - 6s 65ms/step - loss: 0.2005 - accuracy: 0.1241
# Epoch 17/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1989 - accuracy: 0.1188
# Epoch 18/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1973 - accuracy: 0.1261
# Epoch 19/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1958 - accuracy: 0.1297
# Epoch 20/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1944 - accuracy: 0.1320
# Epoch 21/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1930 - accuracy: 0.1336
# Epoch 22/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1916 - accuracy: 0.1327
# Epoch 23/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1903 - accuracy: 0.1373
# Epoch 24/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1890 - accuracy: 0.1396
# Epoch 25/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1878 - accuracy: 0.1415
# 16/16 [==============================] - 6s 391ms/step
# >0.476
# 1
# 2
# Epoch 1/25
# 95/95 [==============================] - 7s 64ms/step - loss: 0.6221 - accuracy: 0.0392
# Epoch 2/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.4396 - accuracy: 0.0362
# Epoch 3/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.3433 - accuracy: 0.0273
# Epoch 4/25
# 95/95 [==============================] - 6s 65ms/step - loss: 0.2917 - accuracy: 0.0214
# Epoch 5/25
# 95/95 [==============================] - 6s 65ms/step - loss: 0.2626 - accuracy: 0.0309
# Epoch 6/25
# 95/95 [==============================] - 6s 65ms/step - loss: 0.2450 - accuracy: 0.0563
# Epoch 7/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2338 - accuracy: 0.0701
# Epoch 8/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2260 - accuracy: 0.0889
# Epoch 9/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2204 - accuracy: 0.0968
# Epoch 10/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2162 - accuracy: 0.0997
# Epoch 11/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2128 - accuracy: 0.1014
# Epoch 12/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2099 - accuracy: 0.1096
# Epoch 13/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2075 - accuracy: 0.1090
# Epoch 14/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2053 - accuracy: 0.1103
# Epoch 15/25
# 95/95 [==============================] - 6s 65ms/step - loss: 0.2033 - accuracy: 0.1159
# Epoch 16/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2014 - accuracy: 0.1155
# Epoch 17/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1997 - accuracy: 0.1172
# Epoch 18/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1981 - accuracy: 0.1192
# Epoch 19/25
# 95/95 [==============================] - 6s 65ms/step - loss: 0.1965 - accuracy: 0.1208
# Epoch 20/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1949 - accuracy: 0.1234
# Epoch 21/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1935 - accuracy: 0.1257
# Epoch 22/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1920 - accuracy: 0.1280
# Epoch 23/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1906 - accuracy: 0.1297
# Epoch 24/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1893 - accuracy: 0.1333
# Epoch 25/25
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1879 - accuracy: 0.1356
# 16/16 [==============================] - 2s 113ms/step
# >0.463
# mAP: 0.465 (0.012)

# %%
file_name = "vgg16_evaluation.csv"
save_path = os.path.join(checkpoint_path, file_name)
df.to_csv(save_path)
