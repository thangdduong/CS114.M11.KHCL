# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import tensorflow as tf
import tensorflow.keras as keras
import os
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import tqdm
from tensorflow.keras.utils import Sequence, to_categorical
from keras.utils.np_utils import to_categorical
import tensorflow_datasets as tfds
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D, Dropout, BatchNormalization, UpSampling2D, InputLayer
from tensorflow.keras.layers import Input
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import average_precision_score

# %% [markdown]
# ## __Load dữ liệu train, test, val__

# %%
# make shorcut cho folder CS114-ML trước
# %cd "/content/gdrive/MyDrive/CS114-ML/data_ndarray"
# Out:
# /content/gdrive/.shortcut-targets-by-id/12IVdVQOkY2icQgpyJaH6y16BPdip3RKW/CS114-ML/data_ndarray

# %%
with open('X.npy', 'rb') as f:
    X = np.load(f)
with open('y.npy', 'rb') as f:
    y = np.load(f)

# %% [markdown]
# ## __Cài đặt mô hình__

# %%
df = pd.DataFrame(columns=["model", "fold_1", "fold_2", "fold_3", "fold_4", "mWAP", "std"])

# %%
# khai báo số lượng class và shape ảnh training
num_classes = y.shape[1]
input_shape = X.shape[1:]

# %%
# training config
base_learning_rate = 0.0001
epochs = 25
batch_size = 64

checkpoint_path = "/content/gdrive/MyDrive/CS114-ML/checkpoint/inception"

callbacks = ModelCheckpoint(
        filepath=os.path.join(checkpoint_path, "inception-{epoch}.h5"),
        save_best_only=True, 
        monitor="val_loss",
        verbose=1)

# %%
def get_model():
  # khai báo mô hình CNN sử dụng
  base_model = tf.keras.applications.InceptionV3(include_top=False, weights="imagenet", input_shape=input_shape)

  # đóng băng (k cập nhật trọng số khi training) toàn bộ base_model
  base_model.trainable = False

  input_layer = tf.keras.Input(shape=input_shape) # khởi tạo input layer

  rescale = tf.keras.layers.Rescaling(1./255) 
  x = rescale(input_layer) # scale ảnh từ [0, 255] về [0, 1]
  x = base_model(x, training=False) # đưa kết quả input_layer vào base_model
  x = tf.keras.layers.GlobalAveragePooling2D()(x) # "flatten" kết quả đầu ra của base_model thành vector 1 chiều

  output_layer = tf.keras.layers.Dense(num_classes, activation="sigmoid")(x) # khởi tạo output layer - dự đoán toàn bộ 

  model = Model(inputs=input_layer, outputs=output_layer) # ghép input layer và output layer lại thành 1 model hoàn chỉnh

  model.compile(loss='binary_crossentropy', 
              optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              metrics=['accuracy'])
  
  return model

# %%
def evaluate_model(X, y):
  ap_results = [] # khai báo biến chứa kết quả ap của từng fold
  
  cv = RepeatedKFold(n_splits=4, n_repeats=1, random_state=1)
  
  for train_ix, test_ix in cv.split(X):
    X_train, X_test = X[train_ix], X[test_ix]
    y_train, y_test = y[train_ix], y[test_ix]
    print("1")

    model = get_model()
    print("2")
    model.fit(X_train, y_train, verbose=1, epochs=epochs)

    y_pred_scores = model.predict(X_test, batch_size=batch_size, verbose=1)
    y_pred_scores = np.around(y_pred_scores, decimals=3)

    weighted_ap = average_precision_score(y_test, y_pred_scores, average='weighted')

    print('>%.3f' % weighted_ap)
    ap_results.append(weighted_ap)

  mwap = np.round(np.mean(ap_results), 3)
  std = np.round(np.std(ap_results), 3)
  print('mAP: %.3f (%.3f)' % (np.mean(ap_results), np.std(ap_results)))
  ap_results = np.around(ap_results, decimals=3)
  df.loc[0] = ["inception"] + [ap_results[0]] + [ap_results[1]] + [ap_results[2]] + [ap_results[3]] + [mwap] + [std]
  return ap_results

# %%
results = evaluate_model(X, y)
# Out:
# 1
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 3s 0us/step
# 87924736/87910968 [==============================] - 3s 0us/step
# 2
# Epoch 1/25
# 95/95 [==============================] - 16s 51ms/step - loss: 0.3093 - accuracy: 0.0454
# Epoch 2/25
# 95/95 [==============================] - 5s 47ms/step - loss: 0.2131 - accuracy: 0.0866
# Epoch 3/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1906 - accuracy: 0.1307
# Epoch 4/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1720 - accuracy: 0.2058
# Epoch 5/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1569 - accuracy: 0.2796
# Epoch 6/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1452 - accuracy: 0.3411
# Epoch 7/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1355 - accuracy: 0.3872
# Epoch 8/25
# 95/95 [==============================] - 5s 47ms/step - loss: 0.1276 - accuracy: 0.4304
# Epoch 9/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1212 - accuracy: 0.4478
# Epoch 10/25
# 95/95 [==============================] - 5s 47ms/step - loss: 0.1158 - accuracy: 0.4610
# Epoch 11/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.1112 - accuracy: 0.4807
# Epoch 12/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1071 - accuracy: 0.4900
# Epoch 13/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1037 - accuracy: 0.5044
# Epoch 14/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1005 - accuracy: 0.5091
# Epoch 15/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.0976 - accuracy: 0.5239
# Epoch 16/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.0950 - accuracy: 0.5295
# Epoch 17/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.0928 - accuracy: 0.5314
# Epoch 18/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.0906 - accuracy: 0.5370
# Epoch 19/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.0887 - accuracy: 0.5387
# Epoch 20/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.0868 - accuracy: 0.5420
# Epoch 21/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.0851 - accuracy: 0.5466
# Epoch 22/25
# 95/95 [==============================] - 5s 49ms/step - loss: 0.0835 - accuracy: 0.5496
# Epoch 23/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.0820 - accuracy: 0.5482
# Epoch 24/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.0805 - accuracy: 0.5512
# Epoch 25/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.0792 - accuracy: 0.5568
# 16/16 [==============================] - 3s 104ms/step
# >0.796
# 1
# 2
# Epoch 1/25
# 95/95 [==============================] - 8s 48ms/step - loss: 0.3019 - accuracy: 0.0619
# Epoch 2/25
# 95/95 [==============================] - 5s 47ms/step - loss: 0.2123 - accuracy: 0.0899
# Epoch 3/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.1894 - accuracy: 0.1396
# Epoch 4/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.1708 - accuracy: 0.2173
# Epoch 5/25
# 95/95 [==============================] - 5s 47ms/step - loss: 0.1559 - accuracy: 0.2822
# Epoch 6/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1443 - accuracy: 0.3461
# Epoch 7/25
# 95/95 [==============================] - 5s 47ms/step - loss: 0.1348 - accuracy: 0.3961
# Epoch 8/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.1271 - accuracy: 0.4284
# Epoch 9/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.1208 - accuracy: 0.4495
# Epoch 10/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.1156 - accuracy: 0.4649
# Epoch 11/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.1111 - accuracy: 0.4817
# Epoch 12/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1072 - accuracy: 0.4936
# Epoch 13/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.1039 - accuracy: 0.5061
# Epoch 14/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.1009 - accuracy: 0.5147
# Epoch 15/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.0983 - accuracy: 0.5179
# Epoch 16/25
# 95/95 [==============================] - 5s 47ms/step - loss: 0.0958 - accuracy: 0.5288
# Epoch 17/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.0937 - accuracy: 0.5308
# Epoch 18/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.0917 - accuracy: 0.5380
# Epoch 19/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.0896 - accuracy: 0.5351
# Epoch 20/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.0879 - accuracy: 0.5390
# Epoch 21/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.0863 - accuracy: 0.5443
# Epoch 22/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.0847 - accuracy: 0.5453
# Epoch 23/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.0833 - accuracy: 0.5469
# Epoch 24/25
# 95/95 [==============================] - 5s 47ms/step - loss: 0.0819 - accuracy: 0.5499
# Epoch 25/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.0805 - accuracy: 0.5538
# 16/16 [==============================] - 2s 75ms/step
# >0.813
# 1
# 2
# Epoch 1/25
# 95/95 [==============================] - 9s 51ms/step - loss: 0.3160 - accuracy: 0.0513
# Epoch 2/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.2149 - accuracy: 0.0866
# Epoch 3/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1923 - accuracy: 0.1359
# Epoch 4/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.1736 - accuracy: 0.2143
# Epoch 5/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.1586 - accuracy: 0.2808
# Epoch 6/25
# 95/95 [==============================] - 5s 47ms/step - loss: 0.1467 - accuracy: 0.3443
# Epoch 7/25
# 95/95 [==============================] - 5s 47ms/step - loss: 0.1369 - accuracy: 0.3762
# Epoch 8/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.1292 - accuracy: 0.4108
# Epoch 9/25
# 95/95 [==============================] - 5s 47ms/step - loss: 0.1227 - accuracy: 0.4394
# Epoch 10/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.1172 - accuracy: 0.4526
# Epoch 11/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.1125 - accuracy: 0.4694
# Epoch 12/25
# 95/95 [==============================] - 5s 47ms/step - loss: 0.1085 - accuracy: 0.4799
# Epoch 13/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.1050 - accuracy: 0.4878
# Epoch 14/25
# 95/95 [==============================] - 5s 47ms/step - loss: 0.1020 - accuracy: 0.4990
# Epoch 15/25
# 95/95 [==============================] - 5s 47ms/step - loss: 0.0991 - accuracy: 0.5118
# Epoch 16/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.0967 - accuracy: 0.5158
# Epoch 17/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.0943 - accuracy: 0.5253
# Epoch 18/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.0922 - accuracy: 0.5309
# Epoch 19/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.0902 - accuracy: 0.5329
# Epoch 20/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.0885 - accuracy: 0.5431
# Epoch 21/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.0867 - accuracy: 0.5408
# Epoch 22/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.0851 - accuracy: 0.5497
# Epoch 23/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.0836 - accuracy: 0.5533
# Epoch 24/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.0822 - accuracy: 0.5494
# Epoch 25/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.0808 - accuracy: 0.5573
# 16/16 [==============================] - 3s 107ms/step
# >0.804
# 1
# 2
# Epoch 1/25
# 95/95 [==============================] - 8s 48ms/step - loss: 0.2975 - accuracy: 0.0635
# Epoch 2/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.2127 - accuracy: 0.1050
# Epoch 3/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1899 - accuracy: 0.1633
# Epoch 4/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1710 - accuracy: 0.2304
# Epoch 5/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1556 - accuracy: 0.3117
# Epoch 6/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1433 - accuracy: 0.3683
# Epoch 7/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1334 - accuracy: 0.4085
# Epoch 8/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1255 - accuracy: 0.4447
# Epoch 9/25
# 95/95 [==============================] - 5s 47ms/step - loss: 0.1190 - accuracy: 0.4674
# Epoch 10/25
# 95/95 [==============================] - 5s 48ms/step - loss: 0.1137 - accuracy: 0.4858
# Epoch 11/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1092 - accuracy: 0.4977
# Epoch 12/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1053 - accuracy: 0.5049
# Epoch 13/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.1019 - accuracy: 0.5194
# Epoch 14/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.0989 - accuracy: 0.5306
# Epoch 15/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.0962 - accuracy: 0.5276
# Epoch 16/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.0939 - accuracy: 0.5379
# Epoch 17/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.0915 - accuracy: 0.5402
# Epoch 18/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.0896 - accuracy: 0.5405
# Epoch 19/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.0877 - accuracy: 0.5434
# Epoch 20/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.0859 - accuracy: 0.5467
# Epoch 21/25
# 95/95 [==============================] - 5s 47ms/step - loss: 0.0843 - accuracy: 0.5540
# Epoch 22/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.0827 - accuracy: 0.5494
# Epoch 23/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.0813 - accuracy: 0.5517
# Epoch 24/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.0800 - accuracy: 0.5560
# Epoch 25/25
# 95/95 [==============================] - 4s 47ms/step - loss: 0.0787 - accuracy: 0.5583
# 16/16 [==============================] - 2s 77ms/step
# >0.793
# mAP: 0.801 (0.008)

# %%
file_name = "inception_evaluation.csv"
save_path = os.path.join(checkpoint_path, file_name)
df.to_csv(save_path)
