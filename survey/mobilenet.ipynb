# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import tensorflow as tf
import tensorflow.keras as keras
import os
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import tqdm
from tensorflow.keras.utils import Sequence, to_categorical
from keras.utils.np_utils import to_categorical
import tensorflow_datasets as tfds
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D, Dropout, BatchNormalization, UpSampling2D, InputLayer
from tensorflow.keras.layers import Input
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import average_precision_score

# %% [markdown]
# ## __Load dữ liệu train, test, val__

# %%
# make shorcut cho folder CS114-ML trước
# %cd "/content/gdrive/MyDrive/CS114-ML/data_ndarray"
# Out:
# /content/gdrive/.shortcut-targets-by-id/12IVdVQOkY2icQgpyJaH6y16BPdip3RKW/CS114-ML/data_ndarray

# %%
with open('X.npy', 'rb') as f:
    X = np.load(f)
with open('y.npy', 'rb') as f:
    y = np.load(f)

# %% [markdown]
# ## __Cài đặt mô hình__

# %%
df = pd.DataFrame(columns=["model", "fold_1", "fold_2", "fold_3", "fold_4", "mWAP", "std"])

# %%
# khai báo số lượng class và shape ảnh training
num_classes = y.shape[1]
input_shape = X.shape[1:]

# %%
# training config
base_learning_rate = 0.0001
epochs = 25
batch_size = 64

checkpoint_path = "/content/gdrive/MyDrive/CS114-ML/checkpoint/mobilenet"

callbacks = ModelCheckpoint(
        filepath=os.path.join(checkpoint_path, "mobilenet-{epoch}.h5"),
        save_best_only=True, 
        monitor="val_loss",
        verbose=1)

# %%
def get_model():
  # khai báo mô hình CNN sử dụng
  base_model = tf.keras.applications.MobileNet(include_top=False, weights="imagenet", input_shape=input_shape)

  # đóng băng (k cập nhật trọng số khi training) toàn bộ base_model
  base_model.trainable = False

  input_layer = tf.keras.Input(shape=input_shape) # khởi tạo input layer

  rescale = tf.keras.layers.Rescaling(1./255) 
  x = rescale(input_layer) # scale ảnh từ [0, 255] về [0, 1]
  x = base_model(x, training=False) # đưa kết quả input_layer vào base_model
  x = tf.keras.layers.GlobalAveragePooling2D()(x) # "flatten" kết quả đầu ra của base_model thành vector 1 chiều

  output_layer = tf.keras.layers.Dense(num_classes, activation="sigmoid")(x) # khởi tạo output layer - dự đoán toàn bộ 

  model = Model(inputs=input_layer, outputs=output_layer) # ghép input layer và output layer lại thành 1 model hoàn chỉnh

  model.compile(loss='binary_crossentropy', 
              optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              metrics=['accuracy'])
  
  return model

# %%
def evaluate_model(X, y):
  ap_results = [] # khai báo biến chứa kết quả ap của từng fold
  
  cv = RepeatedKFold(n_splits=4, n_repeats=1, random_state=1)
  
  for train_ix, test_ix in cv.split(X):
    X_train, X_test = X[train_ix], X[test_ix]
    y_train, y_test = y[train_ix], y[test_ix]
    print("1")

    model = get_model()
    print("2")
    model.fit(X_train, y_train, verbose=1, epochs=epochs)

    y_pred_scores = model.predict(X_test, batch_size=batch_size, verbose=1)
    y_pred_scores = np.around(y_pred_scores, decimals=3)

    weighted_ap = average_precision_score(y_test, y_pred_scores, average='weighted')

    print('>%.3f' % weighted_ap)
    ap_results.append(weighted_ap)

  mwap = np.round(np.mean(ap_results), 3)
  std = np.round(np.std(ap_results), 3)
  print('mAP: %.3f (%.3f)' % (np.mean(ap_results), np.std(ap_results)))
  ap_results = np.around(ap_results, decimals=3)
  df.loc[0] = ["mobile_net"] + [ap_results[0]] + [ap_results[1]] + [ap_results[2]] + [ap_results[3]] + [mwap] + [std]
  return ap_results

# %%
results = evaluate_model(X, y)
# Out:
# 1
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 0s 0us/step
# 17235968/17225924 [==============================] - 0s 0us/step
# 2
# Epoch 1/25
# 95/95 [==============================] - 11s 28ms/step - loss: 0.4117 - accuracy: 0.0484
# Epoch 2/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.2275 - accuracy: 0.0938
# Epoch 3/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.2026 - accuracy: 0.1241
# Epoch 4/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1853 - accuracy: 0.1676
# Epoch 5/25
# 95/95 [==============================] - 3s 26ms/step - loss: 0.1709 - accuracy: 0.2051
# Epoch 6/25
# 95/95 [==============================] - 2s 26ms/step - loss: 0.1587 - accuracy: 0.2470
# Epoch 7/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1483 - accuracy: 0.2868
# Epoch 8/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1395 - accuracy: 0.3260
# Epoch 9/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1320 - accuracy: 0.3556
# Epoch 10/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1255 - accuracy: 0.3820
# Epoch 11/25
# 95/95 [==============================] - 2s 26ms/step - loss: 0.1200 - accuracy: 0.4037
# Epoch 12/25
# 95/95 [==============================] - 3s 26ms/step - loss: 0.1150 - accuracy: 0.4175
# Epoch 13/25
# 95/95 [==============================] - 3s 26ms/step - loss: 0.1108 - accuracy: 0.4277
# Epoch 14/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1070 - accuracy: 0.4396
# Epoch 15/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1035 - accuracy: 0.4541
# Epoch 16/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1006 - accuracy: 0.4590
# Epoch 17/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0977 - accuracy: 0.4709
# Epoch 18/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0952 - accuracy: 0.4784
# Epoch 19/25
# 95/95 [==============================] - 3s 26ms/step - loss: 0.0929 - accuracy: 0.4837
# Epoch 20/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0908 - accuracy: 0.4877
# Epoch 21/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0887 - accuracy: 0.4932
# Epoch 22/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0869 - accuracy: 0.4962
# Epoch 23/25
# 95/95 [==============================] - 3s 26ms/step - loss: 0.0851 - accuracy: 0.5008
# Epoch 24/25
# 95/95 [==============================] - 2s 26ms/step - loss: 0.0835 - accuracy: 0.4998
# Epoch 25/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0820 - accuracy: 0.5094
# 16/16 [==============================] - 1s 53ms/step
# >0.801
# 1
# 2
# Epoch 1/25
# 95/95 [==============================] - 4s 26ms/step - loss: 0.3541 - accuracy: 0.0408
# Epoch 2/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.2231 - accuracy: 0.0784
# Epoch 3/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1999 - accuracy: 0.1103
# Epoch 4/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1823 - accuracy: 0.1581
# Epoch 5/25
# 95/95 [==============================] - 3s 26ms/step - loss: 0.1679 - accuracy: 0.2163
# Epoch 6/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1558 - accuracy: 0.2542
# Epoch 7/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1458 - accuracy: 0.3029
# Epoch 8/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1373 - accuracy: 0.3362
# Epoch 9/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1300 - accuracy: 0.3681
# Epoch 10/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1239 - accuracy: 0.3912
# Epoch 11/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1186 - accuracy: 0.4116
# Epoch 12/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1140 - accuracy: 0.4313
# Epoch 13/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1100 - accuracy: 0.4392
# Epoch 14/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1063 - accuracy: 0.4511
# Epoch 15/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1031 - accuracy: 0.4633
# Epoch 16/25
# 95/95 [==============================] - 2s 26ms/step - loss: 0.1002 - accuracy: 0.4709
# Epoch 17/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0976 - accuracy: 0.4781
# Epoch 18/25
# 95/95 [==============================] - 3s 26ms/step - loss: 0.0952 - accuracy: 0.4870
# Epoch 19/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0930 - accuracy: 0.4929
# Epoch 20/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0909 - accuracy: 0.4936
# Epoch 21/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0890 - accuracy: 0.5058
# Epoch 22/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0873 - accuracy: 0.5110
# Epoch 23/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0856 - accuracy: 0.5094
# Epoch 24/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0840 - accuracy: 0.5133
# Epoch 25/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0825 - accuracy: 0.5137
# 16/16 [==============================] - 1s 45ms/step
# >0.823
# 1
# 2
# Epoch 1/25
# 95/95 [==============================] - 4s 28ms/step - loss: 0.3850 - accuracy: 0.0454
# Epoch 2/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.2259 - accuracy: 0.0675
# Epoch 3/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.2020 - accuracy: 0.1020
# Epoch 4/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1850 - accuracy: 0.1432
# Epoch 5/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1708 - accuracy: 0.1975
# Epoch 6/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1590 - accuracy: 0.2521
# Epoch 7/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1489 - accuracy: 0.3041
# Epoch 8/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1404 - accuracy: 0.3446
# Epoch 9/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1331 - accuracy: 0.3736
# Epoch 10/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1268 - accuracy: 0.3976
# Epoch 11/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1214 - accuracy: 0.4154
# Epoch 12/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1166 - accuracy: 0.4361
# Epoch 13/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1124 - accuracy: 0.4463
# Epoch 14/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1087 - accuracy: 0.4638
# Epoch 15/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1054 - accuracy: 0.4717
# Epoch 16/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1024 - accuracy: 0.4799
# Epoch 17/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0997 - accuracy: 0.4865
# Epoch 18/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0972 - accuracy: 0.4947
# Epoch 19/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0948 - accuracy: 0.5000
# Epoch 20/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0928 - accuracy: 0.5043
# Epoch 21/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0908 - accuracy: 0.5089
# Epoch 22/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0890 - accuracy: 0.5135
# Epoch 23/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0873 - accuracy: 0.5207
# Epoch 24/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0856 - accuracy: 0.5221
# Epoch 25/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0841 - accuracy: 0.5244
# 16/16 [==============================] - 1s 54ms/step
# >0.826
# 1
# 2
# Epoch 1/25
# 95/95 [==============================] - 4s 28ms/step - loss: 0.3645 - accuracy: 0.0513
# Epoch 2/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.2237 - accuracy: 0.0843
# Epoch 3/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.2008 - accuracy: 0.1231
# Epoch 4/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1835 - accuracy: 0.1639
# Epoch 5/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1692 - accuracy: 0.2097
# Epoch 6/25
# 95/95 [==============================] - 3s 28ms/step - loss: 0.1572 - accuracy: 0.2650
# Epoch 7/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1470 - accuracy: 0.3107
# Epoch 8/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1384 - accuracy: 0.3502
# Epoch 9/25
# 95/95 [==============================] - 3s 28ms/step - loss: 0.1311 - accuracy: 0.3743
# Epoch 10/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1248 - accuracy: 0.3989
# Epoch 11/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1193 - accuracy: 0.4144
# Epoch 12/25
# 95/95 [==============================] - 3s 28ms/step - loss: 0.1145 - accuracy: 0.4365
# Epoch 13/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1103 - accuracy: 0.4539
# Epoch 14/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1065 - accuracy: 0.4615
# Epoch 15/25
# 95/95 [==============================] - 3s 28ms/step - loss: 0.1032 - accuracy: 0.4733
# Epoch 16/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.1002 - accuracy: 0.4809
# Epoch 17/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0975 - accuracy: 0.4898
# Epoch 18/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0951 - accuracy: 0.4911
# Epoch 19/25
# 95/95 [==============================] - 3s 28ms/step - loss: 0.0928 - accuracy: 0.4934
# Epoch 20/25
# 95/95 [==============================] - 3s 28ms/step - loss: 0.0907 - accuracy: 0.5036
# Epoch 21/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0887 - accuracy: 0.5043
# Epoch 22/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0869 - accuracy: 0.5092
# Epoch 23/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0852 - accuracy: 0.5132
# Epoch 24/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0836 - accuracy: 0.5132
# Epoch 25/25
# 95/95 [==============================] - 3s 27ms/step - loss: 0.0820 - accuracy: 0.5171
# 16/16 [==============================] - 1s 44ms/step
# >0.814
# mAP: 0.816 (0.010)

# %%
file_name = "mobile_net_evaluation.csv"
save_path = os.path.join(checkpoint_path, file_name)
df.to_csv(save_path)
