# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import tensorflow as tf
import tensorflow.keras as keras
import os
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import tqdm
from tensorflow.keras.utils import Sequence, to_categorical
from keras.utils.np_utils import to_categorical
import tensorflow_datasets as tfds
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D, Dropout, BatchNormalization, UpSampling2D, InputLayer
from tensorflow.keras.layers import Input
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import average_precision_score

# %% [markdown]
# ## __Load dữ liệu train, test, val__

# %%
# make shorcut cho folder CS114-ML trước
# %cd "/content/gdrive/MyDrive/CS114-ML/data_ndarray"
# Out:
# /content/gdrive/.shortcut-targets-by-id/12IVdVQOkY2icQgpyJaH6y16BPdip3RKW/CS114-ML/data_ndarray

# %%
with open('X.npy', 'rb') as f:
    X = np.load(f)
with open('y.npy', 'rb') as f:
    y = np.load(f)

# %% [markdown]
# ## __Cài đặt mô hình__

# %%
df = pd.DataFrame(columns=["model", "fold_1", "fold_2", "fold_3", "fold_4", "mWAP", "std"])

# %%
# khai báo số lượng class và shape ảnh training
num_classes = y.shape[1]
input_shape = X.shape[1:]

# %%
# training config
base_learning_rate = 0.0001
epochs = 25
batch_size = 64

checkpoint_path = "/content/gdrive/MyDrive/CS114-ML/checkpoint/densenet"

callbacks = ModelCheckpoint(
        filepath=os.path.join(checkpoint_path, "densenet-{epoch}.h5"),
        save_best_only=True, 
        monitor="val_loss",
        verbose=1)

# %%
def get_model():
  # khai báo mô hình CNN sử dụng
  base_model = tf.keras.applications.DenseNet121(include_top=False, weights="imagenet", input_shape=input_shape)

  # đóng băng (k cập nhật trọng số khi training) toàn bộ base_model
  base_model.trainable = False

  input_layer = tf.keras.Input(shape=input_shape) # khởi tạo input layer

  rescale = tf.keras.layers.Rescaling(1./255) 
  x = rescale(input_layer) # scale ảnh từ [0, 255] về [0, 1]
  x = base_model(x, training=False) # đưa kết quả input_layer vào base_model
  x = tf.keras.layers.GlobalAveragePooling2D()(x) # "flatten" kết quả đầu ra của base_model thành vector 1 chiều

  output_layer = tf.keras.layers.Dense(num_classes, activation="sigmoid")(x) # khởi tạo output layer - dự đoán toàn bộ 

  model = Model(inputs=input_layer, outputs=output_layer) # ghép input layer và output layer lại thành 1 model hoàn chỉnh

  model.compile(loss='binary_crossentropy', 
              optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              metrics=['accuracy'])
  
  return model

# %%
def evaluate_model(X, y):
  ap_results = [] # khai báo biến chứa kết quả ap của từng fold
  
  cv = RepeatedKFold(n_splits=4, n_repeats=1, random_state=1)
  
  for train_ix, test_ix in cv.split(X):
    X_train, X_test = X[train_ix], X[test_ix]
    y_train, y_test = y[train_ix], y[test_ix]
    print("1")

    model = get_model()
    print("2")
    model.fit(X_train, y_train, verbose=1, epochs=epochs)

    y_pred_scores = model.predict(X_test, batch_size=batch_size, verbose=1)
    y_pred_scores = np.around(y_pred_scores, decimals=3)

    weighted_ap = average_precision_score(y_test, y_pred_scores, average='weighted')

    print('>%.3f' % weighted_ap)
    ap_results.append(weighted_ap)

  mwap = np.round(np.mean(ap_results), 3)
  std = np.round(np.std(ap_results), 3)
  print('mAP: %.3f (%.3f)' % (np.mean(ap_results), np.std(ap_results)))
  ap_results = np.around(ap_results, decimals=3)
  df.loc[0] = ["dense_net"] + [ap_results[0]] + [ap_results[1]] + [ap_results[2]] + [ap_results[3]] + [mwap] + [std]
  return ap_results

# %%
results = evaluate_model(X, y)
# Out:
# 1
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step
# 2
# Epoch 1/25
# 95/95 [==============================] - 19s 64ms/step - loss: 0.4211 - accuracy: 0.0260
# Epoch 2/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.2441 - accuracy: 0.0721
# Epoch 3/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.2187 - accuracy: 0.0965
# Epoch 4/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.2046 - accuracy: 0.1287
# Epoch 5/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1931 - accuracy: 0.1564
# Epoch 6/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1829 - accuracy: 0.1906
# Epoch 7/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1737 - accuracy: 0.2160
# Epoch 8/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1653 - accuracy: 0.2473
# Epoch 9/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1577 - accuracy: 0.2776
# Epoch 10/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1508 - accuracy: 0.3069
# Epoch 11/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1445 - accuracy: 0.3306
# Epoch 12/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1389 - accuracy: 0.3527
# Epoch 13/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1337 - accuracy: 0.3764
# Epoch 14/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1291 - accuracy: 0.3849
# Epoch 15/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1249 - accuracy: 0.4053
# Epoch 16/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1211 - accuracy: 0.4162
# Epoch 17/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1177 - accuracy: 0.4333
# Epoch 18/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1146 - accuracy: 0.4422
# Epoch 19/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1117 - accuracy: 0.4501
# Epoch 20/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1092 - accuracy: 0.4567
# Epoch 21/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1068 - accuracy: 0.4623
# Epoch 22/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1045 - accuracy: 0.4656
# Epoch 23/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1026 - accuracy: 0.4705
# Epoch 24/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1007 - accuracy: 0.4751
# Epoch 25/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.0989 - accuracy: 0.4817
# 16/16 [==============================] - 4s 131ms/step
# >0.780
# 1
# 2
# Epoch 1/25
# 95/95 [==============================] - 11s 58ms/step - loss: 0.4559 - accuracy: 0.0550
# Epoch 2/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.2438 - accuracy: 0.0698
# Epoch 3/25
# 95/95 [==============================] - 6s 58ms/step - loss: 0.2153 - accuracy: 0.0856
# Epoch 4/25
# 95/95 [==============================] - 6s 58ms/step - loss: 0.2010 - accuracy: 0.1070
# Epoch 5/25
# 95/95 [==============================] - 6s 58ms/step - loss: 0.1901 - accuracy: 0.1373
# Epoch 6/25
# 95/95 [==============================] - 6s 58ms/step - loss: 0.1805 - accuracy: 0.1636
# Epoch 7/25
# 95/95 [==============================] - 6s 58ms/step - loss: 0.1721 - accuracy: 0.1949
# Epoch 8/25
# 95/95 [==============================] - 6s 58ms/step - loss: 0.1645 - accuracy: 0.2308
# Epoch 9/25
# 95/95 [==============================] - 6s 58ms/step - loss: 0.1575 - accuracy: 0.2558
# Epoch 10/25
# 95/95 [==============================] - 6s 58ms/step - loss: 0.1513 - accuracy: 0.2865
# Epoch 11/25
# 95/95 [==============================] - 6s 58ms/step - loss: 0.1457 - accuracy: 0.3138
# Epoch 12/25
# 95/95 [==============================] - 6s 58ms/step - loss: 0.1405 - accuracy: 0.3378
# Epoch 13/25
# 95/95 [==============================] - 6s 58ms/step - loss: 0.1357 - accuracy: 0.3606
# Epoch 14/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1315 - accuracy: 0.3777
# Epoch 15/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1277 - accuracy: 0.3935
# Epoch 16/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1241 - accuracy: 0.4106
# Epoch 17/25
# 95/95 [==============================] - 6s 58ms/step - loss: 0.1208 - accuracy: 0.4175
# Epoch 18/25
# 95/95 [==============================] - 6s 58ms/step - loss: 0.1178 - accuracy: 0.4274
# Epoch 19/25
# 95/95 [==============================] - 6s 58ms/step - loss: 0.1151 - accuracy: 0.4360
# Epoch 20/25
# 95/95 [==============================] - 6s 58ms/step - loss: 0.1126 - accuracy: 0.4455
# Epoch 21/25
# 95/95 [==============================] - 6s 58ms/step - loss: 0.1102 - accuracy: 0.4445
# Epoch 22/25
# 95/95 [==============================] - 6s 58ms/step - loss: 0.1080 - accuracy: 0.4524
# Epoch 23/25
# 95/95 [==============================] - 6s 58ms/step - loss: 0.1060 - accuracy: 0.4603
# Epoch 24/25
# 95/95 [==============================] - 6s 58ms/step - loss: 0.1041 - accuracy: 0.4662
# Epoch 25/25
# 95/95 [==============================] - 6s 58ms/step - loss: 0.1023 - accuracy: 0.4679
# 16/16 [==============================] - 3s 96ms/step
# >0.797
# 1
# 2
# Epoch 1/25
# 95/95 [==============================] - 11s 64ms/step - loss: 0.4396 - accuracy: 0.0237
# Epoch 2/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.2448 - accuracy: 0.0517
# Epoch 3/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.2174 - accuracy: 0.0820
# Epoch 4/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.2030 - accuracy: 0.1241
# Epoch 5/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1917 - accuracy: 0.1554
# Epoch 6/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1819 - accuracy: 0.1866
# Epoch 7/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1731 - accuracy: 0.2186
# Epoch 8/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1652 - accuracy: 0.2498
# Epoch 9/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1580 - accuracy: 0.2890
# Epoch 10/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1515 - accuracy: 0.3275
# Epoch 11/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1456 - accuracy: 0.3400
# Epoch 12/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1403 - accuracy: 0.3693
# Epoch 13/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1355 - accuracy: 0.3891
# Epoch 14/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1311 - accuracy: 0.4022
# Epoch 15/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1271 - accuracy: 0.4190
# Epoch 16/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1235 - accuracy: 0.4302
# Epoch 17/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1202 - accuracy: 0.4411
# Epoch 18/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1171 - accuracy: 0.4506
# Epoch 19/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1144 - accuracy: 0.4572
# Epoch 20/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1119 - accuracy: 0.4631
# Epoch 21/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1094 - accuracy: 0.4654
# Epoch 22/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1072 - accuracy: 0.4733
# Epoch 23/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1052 - accuracy: 0.4756
# Epoch 24/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1034 - accuracy: 0.4753
# Epoch 25/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1016 - accuracy: 0.4816
# 16/16 [==============================] - 4s 134ms/step
# >0.791
# 1
# 2
# Epoch 1/25
# 95/95 [==============================] - 11s 59ms/step - loss: 0.4333 - accuracy: 0.0319
# Epoch 2/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.2432 - accuracy: 0.0560
# Epoch 3/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.2177 - accuracy: 0.0770
# Epoch 4/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.2041 - accuracy: 0.1070
# Epoch 5/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1931 - accuracy: 0.1330
# Epoch 6/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1833 - accuracy: 0.1606
# Epoch 7/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1744 - accuracy: 0.1863
# Epoch 8/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1664 - accuracy: 0.2163
# Epoch 9/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1590 - accuracy: 0.2488
# Epoch 10/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1524 - accuracy: 0.2814
# Epoch 11/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1463 - accuracy: 0.3022
# Epoch 12/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1409 - accuracy: 0.3308
# Epoch 13/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1359 - accuracy: 0.3525
# Epoch 14/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1314 - accuracy: 0.3680
# Epoch 15/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1273 - accuracy: 0.3845
# Epoch 16/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1236 - accuracy: 0.4029
# Epoch 17/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1203 - accuracy: 0.4124
# Epoch 18/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1171 - accuracy: 0.4282
# Epoch 19/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1143 - accuracy: 0.4361
# Epoch 20/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1117 - accuracy: 0.4473
# Epoch 21/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1093 - accuracy: 0.4477
# Epoch 22/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1071 - accuracy: 0.4549
# Epoch 23/25
# 95/95 [==============================] - 6s 60ms/step - loss: 0.1051 - accuracy: 0.4625
# Epoch 24/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1031 - accuracy: 0.4648
# Epoch 25/25
# 95/95 [==============================] - 6s 59ms/step - loss: 0.1013 - accuracy: 0.4691
# 16/16 [==============================] - 3s 97ms/step
# >0.775
# mAP: 0.786 (0.009)

# %%
file_name = "dense_net_evaluation.csv"
save_path = os.path.join(checkpoint_path, file_name)
df.to_csv(save_path)
